# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('dataset_Facebook.csv', sep=';')
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.isnull()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0               False  False     False       False         False      False
# 1               False  False     False       False         False      False
# 2               False  False     False       False         False      False
# 3               False  False     False       False         False      False
# 4               False  False     False       False         False      False
# ..                ...    ...       ...         ...           ...        ...
# 495             False  False     False       False         False      False
# 496             False  False     False       False         False      False
# 497             False  False     False       False         False      False
# 498             False  False     False       False         False      False
# 499             False  False     False       False         False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# share                                                                  4
# like                                                                   1
# Paid                                                                   1
# Page total likes                                                       0
# Lifetime Post Consumers                                                0
# comment                                                                0
# Lifetime People who have liked your Page and engaged with your post    0
# Lifetime Post reach by people who like your Page                       0
# Lifetime Post Impressions by people who have liked your Page           0
# Lifetime Post Consumptions                                             0
# Lifetime Engaged Users                                                 0
# Type                                                                   0
# Lifetime Post Total Impressions                                        0
# ...

# %%
df.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df['like'].fillna(df['like'].mean())
# Out:
# 0        79.0
# 1       130.0
# 2        66.0
# 3      1572.0
# 4       325.0
#         ...
# 495      53.0
# 496      53.0
# 497      93.0
# 498      91.0
# 499      91.0
# Name: like, Length: 500, dtype: float64

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df.rename(columns={'Page total likes':'Page_total_likes'})
# Out:
#      Page_total_likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Category
# 1    215
# 3    155
# 2    130
# Name: count, dtype: int64

# %%
df[df['Paid'] == 1]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 473             91116  Photo         3           2             2          4
# 475             86909  Photo         3           1             6         16
# 476             86909  Photo         1           1             6         10
# 481             86491   Link         1           1             4          4
# 491             85979  Photo         3           1             6          3
#
# ...

# %%
df[df['like'] > 500]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441   Photo         2          12             2         10
# 14             138414   Photo         2          12             4          5
# 17             138414   Photo         1          12             2         12
# 28             138895   Photo         2          12             5          3
# 67             138185   Photo         1          11             7          3
# 101            137020   Photo         2          10             4          3
# 105            137020   Photo         1          10             2          4
# 142            136013  Status         2          10             3          2
# 168            135428   Photo         1           9             3         10
# 176            135195   Photo         3           9             6          3
# 191            133679   Photo         3           8             1         10
# ...

# %%
df['Engagement_Rate'] = df['Total Interactions'] / df['Lifetime Post Total Reach']
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
subset_columns = df[['Type', 'like', 'share', 'comment']]
subset_columns
# Out:
#        Type    like  share  comment
# 0     Photo    79.0   17.0        4
# 1    Status   130.0   29.0        5
# 2     Photo    66.0   14.0        0
# 3     Photo  1572.0  147.0       58
# 4     Photo   325.0   49.0       19
# ..      ...     ...    ...      ...
# 495   Photo    53.0   26.0        5
# 496   Photo    53.0   22.0        0
# 497   Photo    93.0   18.0        4
# 498   Photo    91.0   38.0        7
# 499   Photo    91.0   28.0        0
#
# [500 rows x 4 columns]

# %%
subset_rows = df.head(10)
subset_rows
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
# 9            139441   Photo         3          12             6         10
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# ...

# %%
paid_posts = df[df['Paid'] == 1]
paid_posts
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 3              139441  Photo         2          12             2         10
# 6              139441  Photo         3          12             1          3
# 7              139441  Photo         3          12             7          9
# 14             138414  Photo         2          12             4          5
# 17             138414  Photo         1          12             2         12
# ..                ...    ...       ...         ...           ...        ...
# 473             91116  Photo         3           2             2          4
# 475             86909  Photo         3           1             6         16
# 476             86909  Photo         1           1             6         10
# 481             86491   Link         1           1             4          4
# 491             85979  Photo         3           1             6          3
#
# ...

# %%
df1 = df[['Type', 'like']]
df2 = df[['Type', 'share']]

# %%
merged_data = pd.merge(df1, df2, on='Type')
merged_data
# Out:
#          Type  like  share
# 0       Photo  79.0   17.0
# 1       Photo  79.0   14.0
# 2       Photo  79.0  147.0
# 3       Photo  79.0   49.0
# 4       Photo  79.0   27.0
# ...       ...   ...    ...
# 184029  Photo  91.0   26.0
# 184030  Photo  91.0   22.0
# 184031  Photo  91.0   18.0
# 184032  Photo  91.0   38.0
# 184033  Photo  91.0   28.0
#
# [184034 rows x 3 columns]

# %%
df.sort_values(by='like')
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 21             138414  Photo         1          12             7         10
# 417            104070  Photo         1           3             3         10
# 100            137020  Photo         1          10             4          9
# 76             137893  Photo         1          11             3          2
# 441             98195  Photo         1           3             5          4
# ..                ...    ...       ...         ...           ...        ...
# 168            135428  Photo         1           9             3         10
# 349            117764  Photo         3           5             5         13
# 379            111620  Photo         3           4             1         14
# 244            130791  Photo         2           7             3          5
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df.sort_values(by='like', ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 379            111620  Photo         3           4             1         14
# 349            117764  Photo         3           5             5         13
# 168            135428  Photo         1           9             3         10
# 3              139441  Photo         2          12             2         10
# ..                ...    ...       ...         ...           ...        ...
# 21             138414  Photo         1          12             7         10
# 100            137020  Photo         1          10             4          9
# 441             98195  Photo         1           3             5          4
# 417            104070  Photo         1           3             3         10
# 111            136736  Photo         1          10             6          8
#
# ...

# %%
df.sort_values(by=['Type', 'like'])
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 481             86491   Link         1           1             4          4
# 430            100732   Link         1           3             7         14
# 49             138353   Link         1          12             2          2
# 485             86491   Link         1           1             2          2
# 22             138414   Link         1          12             7         10
# ..                ...    ...       ...         ...           ...        ...
# 29             138895  Video         1          12             4         11
# 277            126424  Video         1           6             2         13
# 243            130791  Video         1           7             3         11
# 183            134879  Video         1           9             2         10
# 71             137893  Video         1          11             5          3
#
# ...

# %%
df_transposed = df.head().T
df_transposed
# Out:
#                                                            0         1  \
# Page total likes                                      139441    139441
# Type                                                   Photo    Status
# Category                                                   2         2
# Post Month                                                12        12
# Post Weekday                                               4         3
# Post Hour                                                  3        10
# Paid                                                     0.0       0.0
# Lifetime Post Total Reach                               2752     10460
# Lifetime Post Total Impressions                         5091     19057
# Lifetime Engaged Users                                   178      1457
# Lifetime Post Consumers                                  109      1361
# Lifetime Post Consumptions                               159      1674
# ...

# %%
df.shape
# Out:
# (500, 20)

# %%
arr = np.array(df['like'].head(10))
arr.reshape(5,2)
# Out:
# array([[  79.,  130.],
#        [  66., 1572.],
#        [ 325.,  152.],
#        [ 249.,  325.],
#        [ 161.,  113.]])

# %%
pivot_table = df.pivot_table(
    values='Total Interactions',
    index='Type',
    columns='Paid',
    aggfunc='mean'
)
pivot_table
# Out:
# Paid           0.0         1.0
# Type
# Link     95.812500   71.000000
# Photo   191.248366  282.537815
# Status  181.571429  341.200000
# Video   285.666667  303.500000

# %%
melted_data = pd.melt(
    df,
    id_vars=['Type'],
    value_vars=['like', 'share', 'comment']
)
melted_data
# Out:
#         Type variable   value
# 0      Photo     like    79.0
# 1     Status     like   130.0
# 2      Photo     like    66.0
# 3      Photo     like  1572.0
# 4      Photo     like   325.0
# ...      ...      ...     ...
# 1495   Photo  comment     5.0
# 1496   Photo  comment     0.0
# 1497   Photo  comment     4.0
# 1498   Photo  comment     7.0
# 1499   Photo  comment     0.0
#
# [1500 rows x 3 columns]
